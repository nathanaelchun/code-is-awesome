# %%
import pandas as pd

# %%
df= pd.read_csv("/Users/nathanaelchun/Downloads/chelsea.csv")

# %%
df
# Out:
#       id          player_name  games  time  goals         xG  assists  \
# 0    702        Tammy Abraham     34  2233     15  18.082802        3
# 1    700              Willian     36  2609      9   8.135337        7
# 2   2662    Christian Pulisic     25  1738      9   8.925186        4
# 3    502       Olivier Giroud     18  1015      8   7.400898        0
# 4   7768          Mason Mount     37  2894      7   7.497830        5
# 5   1389             Jorginho     31  2391      4   3.097004        2
# 6   1621        Marcos Alonso     18  1436      4   2.546826        2
# 7    751         N'Golo Kanté     22  1733      3   1.543913        0
# 8    681    César Azpilicueta     36  3234      2   2.594344        6
# 9   1822      Antonio Rüdiger     20  1710      2   0.930455        0
# 10   592         Ross Barkley     21  1100      1   2.844964        4
# 11   687                Pedro     11   661      1   2.472475        1
# ...

# %%
df.columns
# Out:
# Index(['id', 'player_name', 'games', 'time', 'goals', 'xG', 'assists', 'xA',
#        'shots', 'key_passes', 'yellow_cards', 'red_cards', 'position',
#        'team_title', 'npg', 'npxG', 'xGChain', 'xGBuildup'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27, step=1)

# %%
df.player_name
# Out:
# 0           Tammy Abraham
# 1                 Willian
# 2       Christian Pulisic
# 3          Olivier Giroud
# 4             Mason Mount
# 5                Jorginho
# 6           Marcos Alonso
# 7            N'Golo Kanté
# 8       César Azpilicueta
# 9         Antonio Rüdiger
# 10           Ross Barkley
# 11                  Pedro
# 12          Fikayo Tomori
# 13        Michy Batshuayi
# 14          Mateo Kovacic
# 15     Callum Hudson-Odoi
# 16    Andreas Christensen
# 17        Willy Caballero
# 18     Ruben Loftus-Cheek
# 19             Kurt Zouma
# 20                Emerson
# 21                   Kepa
# 22          Billy Gilmour
# 23            Reece James
# 24          Tariq Lamptey
# 25       Faustino Anjorin
# 26          Armando Broja
# Name: player_name, dtype: object

# %%
df.goals
# Out:
# 0     15
# 1      9
# 2      9
# 3      8
# 4      7
# 5      4
# 6      4
# 7      3
# 8      2
# 9      2
# 10     1
# 11     1
# 12     1
# 13     1
# 14     1
# 15     1
# 16     0
# 17     0
# 18     0
# 19     0
# 20     0
# 21     0
# 22     0
# 23     0
# 24     0
# 25     0
# 26     0
# Name: goals, dtype: int64

# %%
df.loc[:,:]
# Out:
#       id          player_name  games  time  goals         xG  assists  \
# 0    702        Tammy Abraham     34  2233     15  18.082802        3
# 1    700              Willian     36  2609      9   8.135337        7
# 2   2662    Christian Pulisic     25  1738      9   8.925186        4
# 3    502       Olivier Giroud     18  1015      8   7.400898        0
# 4   7768          Mason Mount     37  2894      7   7.497830        5
# 5   1389             Jorginho     31  2391      4   3.097004        2
# 6   1621        Marcos Alonso     18  1436      4   2.546826        2
# 7    751         N'Golo Kanté     22  1733      3   1.543913        0
# 8    681    César Azpilicueta     36  3234      2   2.594344        6
# 9   1822      Antonio Rüdiger     20  1710      2   0.930455        0
# 10   592         Ross Barkley     21  1100      1   2.844964        4
# 11   687                Pedro     11   661      1   2.472475        1
# ...

# %%
df.loc[:,["player_name","assists"]]
# Out:
#             player_name  assists
# 0         Tammy Abraham        3
# 1               Willian        7
# 2     Christian Pulisic        4
# 3        Olivier Giroud        0
# 4           Mason Mount        5
# 5              Jorginho        2
# 6         Marcos Alonso        2
# 7          N'Golo Kanté        0
# 8     César Azpilicueta        6
# 9       Antonio Rüdiger        0
# 10         Ross Barkley        4
# 11                Pedro        1
# 12        Fikayo Tomori        0
# 13      Michy Batshuayi        1
# 14        Mateo Kovacic        3
# 15   Callum Hudson-Odoi        5
# 16  Andreas Christensen        0
# 17      Willy Caballero        0
# 18   Ruben Loftus-Cheek        1
# 19           Kurt Zouma        0
# 20              Emerson        0
# 21                 Kepa        0
# 22        Billy Gilmour        0
# 23          Reece James        2
# 24        Tariq Lamptey        0
# 25     Faustino Anjorin        0
# 26        Armando Broja        0

# %%
df.loc[:,["player_name","assists"]].sort_values("assists")
# Out:
#             player_name  assists
# 26        Armando Broja        0
# 24        Tariq Lamptey        0
# 22        Billy Gilmour        0
# 3        Olivier Giroud        0
# 21                 Kepa        0
# 20              Emerson        0
# 19           Kurt Zouma        0
# 7          N'Golo Kanté        0
# 9       Antonio Rüdiger        0
# 17      Willy Caballero        0
# 16  Andreas Christensen        0
# 12        Fikayo Tomori        0
# 25     Faustino Anjorin        0
# 18   Ruben Loftus-Cheek        1
# 13      Michy Batshuayi        1
# 11                Pedro        1
# 6         Marcos Alonso        2
# 5              Jorginho        2
# 23          Reece James        2
# 14        Mateo Kovacic        3
# 0         Tammy Abraham        3
# 10         Ross Barkley        4
# 2     Christian Pulisic        4
# 15   Callum Hudson-Odoi        5
# 4           Mason Mount        5
# 8     César Azpilicueta        6
# 1               Willian        7

# %%
df2 = df.loc[:,["player_name","assists"]]

# %%
df2.sort_values("assists",ascending=False)
# Out:
#             player_name  assists
# 1               Willian        7
# 8     César Azpilicueta        6
# 4           Mason Mount        5
# 15   Callum Hudson-Odoi        5
# 2     Christian Pulisic        4
# 10         Ross Barkley        4
# 0         Tammy Abraham        3
# 14        Mateo Kovacic        3
# 23          Reece James        2
# 5              Jorginho        2
# 6         Marcos Alonso        2
# 18   Ruben Loftus-Cheek        1
# 13      Michy Batshuayi        1
# 11                Pedro        1
# 12        Fikayo Tomori        0
# 9       Antonio Rüdiger        0
# 16  Andreas Christensen        0
# 17      Willy Caballero        0
# 7          N'Golo Kanté        0
# 19           Kurt Zouma        0
# 20              Emerson        0
# 21                 Kepa        0
# 22        Billy Gilmour        0
# 3        Olivier Giroud        0
# 24        Tariq Lamptey        0
# 25     Faustino Anjorin        0
# 26        Armando Broja        0
