# %%
print(9*9)
# Out:
# 81

# %%
5*9
# Out:
# 45

# %%
# !ls
# Out:
# Untitled.ipynb chelsea.csv

# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.6 MB 134 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.3 MB 22.9 MB/s eta 0:00:01   |███▉                            | 1.9 MB 2.4 MB/s eta 0:00:06     |██████████▏                     | 4.9 MB 2.4 MB/s eta 0:00:05     |████████████████████            | 9.5 MB 2.4 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

# %%
df_players = pd.read_csv("chelsea.csv")

# %%
df_players
# Out:
#       id          player_name  games  time  goals         xG  assists  \
# 0    702        Tammy Abraham     34  2233     15  18.082802        3
# 1    700              Willian     36  2609      9   8.135337        7
# 2   2662    Christian Pulisic     25  1738      9   8.925186        4
# 3    502       Olivier Giroud     18  1015      8   7.400898        0
# 4   7768          Mason Mount     37  2894      7   7.497830        5
# 5   1389             Jorginho     31  2391      4   3.097004        2
# 6   1621        Marcos Alonso     18  1436      4   2.546826        2
# 7    751    N&#039;Golo Kanté     22  1733      3   1.543913        0
# 8    681    César Azpilicueta     36  3234      2   2.594344        6
# 9   1822      Antonio Rüdiger     20  1710      2   0.930455        0
# 10   592         Ross Barkley     21  1100      1   2.844964        4
# 11   687                Pedro     11   661      1   2.472475        1
# ...

# %%
#estimate goals
# 1 tammy abraham
# 2 pulisc
# 3 giroud
# 4 willian
# 5 ceaser az

# estimate assist
# 1 ceaser az
# 2 pulisc
# 3 jorjinho
# 4 willian
# 5 giroud

# %%
df_players.sort_values(by="goals",ascending=False).head(5)
# Out:
#      id        player_name  games  time  goals         xG  assists        xA  \
# 0   702      Tammy Abraham     34  2233     15  18.082802        3  2.913048
# 1   700            Willian     36  2609      9   8.135337        7  8.679427
# 2  2662  Christian Pulisic     25  1738      9   8.925186        4  4.296080
# 3   502     Olivier Giroud     18  1015      8   7.400898        0  1.388367
# 4  7768        Mason Mount     37  2894      7   7.497830        5  5.258457
#
#    shots  key_passes  yellow_cards  red_cards position team_title  npg  \
# 0     88          21             2          0      F S    Chelsea   15
# 1     71          76             4          0    F M S    Chelsea    5
# 2     63          30             0          0    F M S    Chelsea    9
# 3     39           8             1          0      F S    Chelsea    8
# 4     78          52             3          0    F M S    Chelsea    7
#
#         npxG    xGChain  xGBuildup
# 0  18.082802  19.841920   1.546151
# ...

# %%
df_players.sort_values(by="assists",ascending=False).head(5)
# Out:
#       id         player_name  games  time  goals        xG  assists        xA  \
# 1    700             Willian     36  2609      9  8.135337        7  8.679427
# 8    681   César Azpilicueta     36  3234      2  2.594344        6  6.033903
# 4   7768         Mason Mount     37  2894      7  7.497830        5  5.258457
# 15  6456  Callum Hudson-Odoi     22   816      1  2.015143        5  2.708166
# 2   2662   Christian Pulisic     25  1738      9  8.925186        4  4.296080
#
#     shots  key_passes  yellow_cards  red_cards position team_title  npg  \
# 1      71          76             4          0    F M S    Chelsea    5
# 8      29          45             1          0      D M    Chelsea    2
# 4      78          52             3          0    F M S    Chelsea    7
# 15     21          20             1          0    F M S    Chelsea    1
# 2      63          30             0          0    F M S    Chelsea    9
#
#         npxG    xGChain  xGBuildup
# ...

# %%
df_players.goals
# Out:
# 0     15
# 1      9
# 2      9
# 3      8
# 4      7
# 5      4
# 6      4
# 7      3
# 8      2
# 9      2
# 10     1
# 11     1
# 12     1
# 13     1
# 14     1
# 15     1
# 16     0
# 17     0
# 18     0
# 19     0
# 20     0
# 21     0
# 22     0
# 23     0
# 24     0
# 25     0
# 26     0
# Name: goals, dtype: int64

# %%
df_players.shots
# Out:
# 0     88
# 1     71
# 2     63
# 3     39
# 4     78
# 5     12
# 6     30
# 7     18
# 8     29
# 9     12
# 10    40
# 11    22
# 12     7
# 13    15
# 14    21
# 15    21
# 16     7
# 17     0
# 18     4
# 19    15
# 20    13
# 21     0
# 22     1
# 23    18
# 24     0
# 25     1
# 26     0
# Name: shots, dtype: int64

# %%
df_players.goals/df_players.shots*100
# Out:
# 0     17.045455
# 1     12.676056
# 2     14.285714
# 3     20.512821
# 4      8.974359
# 5     33.333333
# 6     13.333333
# 7     16.666667
# 8      6.896552
# 9     16.666667
# 10     2.500000
# 11     4.545455
# 12    14.285714
# 13     6.666667
# 14     4.761905
# 15     4.761905
# 16     0.000000
# 17          NaN
# 18     0.000000
# 19     0.000000
# 20     0.000000
# 21          NaN
# 22     0.000000
# 23     0.000000
# 24          NaN
# 25     0.000000
# 26          NaN
# dtype: float64

# %%
df_players = df_players.assign(goal_percentage=df_players.goals/df_players.shots*100)

# %%
df_players
# Out:
#       id          player_name  games  time  goals         xG  assists  \
# 0    702        Tammy Abraham     34  2233     15  18.082802        3
# 1    700              Willian     36  2609      9   8.135337        7
# 2   2662    Christian Pulisic     25  1738      9   8.925186        4
# 3    502       Olivier Giroud     18  1015      8   7.400898        0
# 4   7768          Mason Mount     37  2894      7   7.497830        5
# 5   1389             Jorginho     31  2391      4   3.097004        2
# 6   1621        Marcos Alonso     18  1436      4   2.546826        2
# 7    751    N&#039;Golo Kanté     22  1733      3   1.543913        0
# 8    681    César Azpilicueta     36  3234      2   2.594344        6
# 9   1822      Antonio Rüdiger     20  1710      2   0.930455        0
# 10   592         Ross Barkley     21  1100      1   2.844964        4
# 11   687                Pedro     11   661      1   2.472475        1
# ...

# %%
df_players.sort_values(by="goal_percentage",ascending=False)
# Out:
#       id          player_name  games  time  goals         xG  assists  \
# 5   1389             Jorginho     31  2391      4   3.097004        2
# 3    502       Olivier Giroud     18  1015      8   7.400898        0
# 0    702        Tammy Abraham     34  2233     15  18.082802        3
# 7    751    N&#039;Golo Kanté     22  1733      3   1.543913        0
# 9   1822      Antonio Rüdiger     20  1710      2   0.930455        0
# 2   2662    Christian Pulisic     25  1738      9   8.925186        4
# 12   703        Fikayo Tomori     15  1299      1   0.562975        0
# 6   1621        Marcos Alonso     18  1436      4   2.546826        2
# 1    700              Willian     36  2609      9   8.135337        7
# 4   7768          Mason Mount     37  2894      7   7.497830        5
# 8    681    César Azpilicueta     36  3234      2   2.594344        6
# 13  1678      Michy Batshuayi     16   194      1   3.038819        1
# ...
